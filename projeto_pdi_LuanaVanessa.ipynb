# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Helena/PDI_ProcessamentoDeImagensDigitais/blob/main/projeto_pdi_LuanaVanessa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importação das Bibliotecas

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
METODO = cv2.THRESH_BINARY_INV

# %% [markdown]
# # Imagem Luana

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b25593f7-bce9-4bbb-9ccb-74c8f0343f8e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b25593f7-bce9-4bbb-9ccb-74c8f0343f8e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4942_19970222_12.tif to TCGA_CS_4942_19970222_12.tif

# %%
img1 = cv2.imread('TCGA_CS_4942_19970222_12.tif', cv2.IMREAD_UNCHANGED)

# %%
plt.figure(figsize=(8,20))
plt.imshow(img1)
plt.title('Imagem Brain BGR')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
img_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(8,20))
plt.imshow(img_rgb)
plt.title('Imagem Brain RGB')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Importação das Imagens

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d35d893-9947-46d1-b5c7-c9192334ff16" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d35d893-9947-46d1-b5c7-c9192334ff16">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle (2).json to kaggle (2) (1).json

# %%
# !pip install kaggle --upgrade
# Out:
# Requirement already up-to-date: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# ...

# %%
# !mkdir -p ~/.kaggle

# %%
# !mkdir ~/.kaggle
# !cp /root/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: cannot stat '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !ls ~/.kaggle

# %%
# !kaggle competitions list
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
# !kaggle competitions list --sort-by prize
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python2.7/dist-packages/kaggle/api/kaggle_api_extended.py", line 146, in authenticate
#     self.config_file, self.config_dir))
# IOError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %% [markdown]
# # Segmentando as imagens Luana

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e46a1801-bc75-40f2-913e-38a4bcebc25f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e46a1801-bc75-40f2-913e-38a4bcebc25f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4942_19970222_10_mask.tif to TCGA_CS_4942_19970222_10_mask.tif

# %%
img1_seg = cv2.imread('TCGA_CS_4942_19970222_10_mask.tif', cv2.IMREAD_UNCHANGED)

# %%
plt.figure(figsize=(8,20))
plt.imshow(img1_seg)
plt.title('Imagem Brain Segmentada')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Importação e Segmentando as imagens Vanessa

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1e90fa8b-1aed-4b6a-b355-2b4396c55cc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1e90fa8b-1aed-4b6a-b355-2b4396c55cc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4941_19960909_16.tif to TCGA_CS_4941_19960909_16.tif

# %%
img2 = cv2.imread('TCGA_CS_4941_19960909_16.tif', cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img2)

# %%
grayTwo = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayTwo, cmap='gray')

# %%
grayThree = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(grayThree)

# %%
imgtest3 = cv2.cvtColor(grayThree,cv2.COLOR_RGB2GRAY)
plt.imshow(imgtest3, cmap='gray')

# %%
METODO = cv2.THRESH_BINARY_INV
ret, thresh = cv2.threshold(imgtest3,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img2, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(thresh, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
ret, thresh = cv2.threshold(imgtest3,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
plt.imshow(thresh, cmap='gray')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-92026009-b695-49ce-b974-4bae434fee8c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-92026009-b695-49ce-b974-4bae434fee8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4941_19960909_14.tif to TCGA_CS_4941_19960909_14.tif

# %%
img3 = cv2.imread('TCGA_CS_4941_19960909_14.tif', cv2.IMREAD_UNCHANGED)

# %%
plt.imshow(img3)

# %%
grayThree = cv2.cvtColor(img3,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(grayThree,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
grayThree1 = cv2.cvtColor(img3,cv2.COLOR_RGB2GRAY)
plt.imshow(img3, cmap='gray')

# %%
imgEqualizada = cv2.equalizeHist(grayThree)

# %%
fig5 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig5.add_subplot(1, 2, 1)
x1_plt.hist(img3.ravel(),256,[0,256])
x2_plt = fig5.add_subplot(1, 2, 2)
x2_plt.hist(imgEqualizada.ravel(),256,[0,256])
plt.show()

# %%
ret, thresh = cv2.threshold(imgEqualizada,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_)
plt.imshow(thresh, cmap='gray')

# %%
METODO = cv2.THRESH_BINARY_INV
ret, thresh1 = cv2.threshold(imgEqualizada,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img3, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(thresh1, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
METODO = cv2.THRESH_BINARY_INV
ret, thresh1 = cv2.threshold(grayThree1,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img3, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(thresh1, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d82ac9f-0bcc-4e88-b603-f7ea5adbec09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d82ac9f-0bcc-4e88-b603-f7ea5adbec09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4941_19960909_17.tif to TCGA_CS_4941_19960909_17.tif

# %%
img4 = cv2.imread('TCGA_CS_4941_19960909_17.tif', cv2.IMREAD_UNCHANGED)
plt.imshow(img4)

# %%
grayFor = cv2.cvtColor(img4,cv2.COLOR_BGR2GRAY)
ret, thresh4 = cv2.threshold(grayFor,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(thresh4)

# %%
grayFor1 = cv2.cvtColor(img4,cv2.COLOR_RGB2GRAY)
plt.imshow(img4, cmap='gray')

# %%
METODO = cv2.THRESH_BINARY_INV
ret, thresh2 = cv2.threshold(grayFor1,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img4, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(thresh2, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd301d71-595e-46d7-939e-7de64c5c3b58" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd301d71-595e-46d7-939e-7de64c5c3b58">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4941_19960909_11.tif to TCGA_CS_4941_19960909_11.tif

# %%
img5 = cv2.imread('TCGA_CS_4941_19960909_11.tif', cv2.IMREAD_UNCHANGED)
plt.imshow(img5)

# %%
grayFive = cv2.cvtColor(img5,cv2.COLOR_BGR2GRAY)
ret, thresh5 = cv2.threshold(grayFive,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(thresh5,cmap='gray')

# %%
grayFive1 = cv2.cvtColor(img5,cv2.COLOR_RGB2GRAY)
plt.imshow(img5, cmap='gray')

# %%
METODO = cv2.THRESH_BINARY_INV
ret, threshFive = cv2.threshold(grayFive1,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img5, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(threshFive, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d2bb4b39-3ed0-4bab-ae78-8c6fb6b16ead" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2bb4b39-3ed0-4bab-ae78-8c6fb6b16ead">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TCGA_CS_4941_19960909_15.tif to TCGA_CS_4941_19960909_15.tif

# %%
img6 = cv2.imread('TCGA_CS_4941_19960909_15.tif', cv2.IMREAD_UNCHANGED)
plt.imshow(img6)

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)

# %%
plt.imshow(thresh6,cmap='gray')

# %%
graySix1 = cv2.cvtColor(img6,cv2.COLOR_RGB2GRAY)
plt.imshow(img6, cmap='gray')

# %%
ret, threshSix = cv2.threshold(graySix1,80,255,METODO)
fig = plt.figure(figsize=(15,15))

ax1 = fig.add_subplot(221)
plt.imshow(img6, cmap='gray')
plt.title('Imagem Original')

ax1 = fig.add_subplot(222)
plt.imshow(threshSix, cmap='gray')
plt.title('Imagem Segmentada')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# # Descrição das imagens

# %% [markdown]
# # Referências

# %%
https://www.pyimagesearch.com/2021/04/28/opencv-thresholding-cv2-threshold/

# %% [markdown]
# ### THRESH

# %% [markdown]
# MASK

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,100,255,cv2.THRESH_BINARY_INV+cv2.THRESH_MASK)
plt.imshow(thresh6,cmap='gray')

# %% [markdown]
# TOZERO

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_TOZERO)
plt.imshow(thresh6,cmap='gray')

# %% [markdown]
# TOZERO INV

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,80,255,cv2.THRESH_BINARY_INV+cv2.THRESH_TOZERO_INV)
plt.imshow(thresh6,cmap='gray')

# %% [markdown]
# TRIANGLE

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,100,255,cv2.THRESH_BINARY_INV+cv2.THRESH_TRIANGLE)
plt.imshow(thresh6,cmap='gray')

# %% [markdown]
# TRUNC

# %%
graySix = cv2.cvtColor(img6,cv2.COLOR_BGR2GRAY)
ret, thresh6 = cv2.threshold(graySix,20,255,cv2.THRESH_BINARY_INV+cv2.THRESH_TRUNC)
plt.imshow(thresh6,cmap='gray')

# %% [markdown]
# adaptativo
