# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanessa-Helena/PDI_ProcessamentoDeImagensDigitais/blob/main/Aula_5_%E2%80%93_Histograma_Exerc%C3%ADcios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# a)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import files
# %matplotlib inline
uploaded = files.upload()
# Out:
#      <input type="file" id="files-db1744a2-fd88-4dbc-b3ee-ea108328f2ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-db1744a2-fd88-4dbc-b3ee-ea108328f2ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cantor.png to cantor.png

# %%
img = cv2.imread('cantor.png')

# %%
imgRGB = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)

# %%
plt.imshow(imgRGB)

# %%
imgEqualizada = cv2.equalizeHist(imgRGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-59-baed31cd7a89> in <module>()
# ----> 1 imgEqualizada = cv2.equalizeHist(imgRGB)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/histogram.cpp:3429: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'equalizeHist'

# %%
fig4 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig4.add_subplot(1, 2, 1)
x1_plt.imshow(imgRGB,cmap=plt.cm.brg)
x2_plt = fig4.add_subplot(1, 2, 2)
x2_plt.imshow(imgEqualizada,cmap=plt.cm.brg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-03cfc1271a17> in <module>()
#       4 x1_plt.imshow(imgRGB,cmap=plt.cm.brg)
#       5 x2_plt = fig4.add_subplot(1, 2, 2)
# ----> 6 x2_plt.imshow(imgEqualizada,cmap=plt.cm.brg)
#
# NameError: name 'imgEqualizada' is not defined

# %% [markdown]
# b)

# %%
fig5 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig5.add_subplot(1, 2, 1)
x1_plt.hist(imgRGB.ravel(),256,[0,256])
x2_plt = fig5.add_subplot(1, 2, 2)
x2_plt.hist(imgEqualizada.ravel(),256,[0,256])
plt.show()

# %% [markdown]
# C) Da para observar que o primeiro histograma há um pico de cor no nivel 0 e uma pequena distribuição detro do grafico a segunda faz uma distribuição igualada entre todo o histograma

# %% [markdown]
# 2 a)

# %%
from google.colab import files
# %matplotlib inline
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a0b58b2-d4ca-4010-9f0b-6978e29ab7b1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a0b58b2-d4ca-4010-9f0b-6978e29ab7b1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 58368539.jpeg to 58368539.jpeg

# %%
img2 = cv2.imread('58368539.jpeg')

# %% [markdown]
# b)

# %%
img = cv2.imread("58368539.jpeg")
imgbB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgCinza = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
cv2.imwrite("58368539_gray.jpeg", imgCinza)
gray_img = cv2.imread("58368539_gray.jpeg")

# %%
plt.imshow(gray_img)

# %% [markdown]
# c)

# %%
fig6 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig6.add_subplot(1, 2, 1)
x1_plt.hist(imgbB.ravel(),256,[0,256])
x2_plt = fig6.add_subplot(1, 2, 2)
x2_plt.hist(gray_img.ravel(),256,[0,256])
plt.show()

# %% [markdown]
# d)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-aa820749-85bc-40cc-bb81-b771aba0e090" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa820749-85bc-40cc-bb81-b771aba0e090">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving img_gray.png to img_gray.png

# %%
img_NC = cv2.imread("img_gray.png", cv2.IMREAD_GRAYSCALE)

# %%
imgGrayequalizada = cv2.equalizeHist(img_NC)

# %%
imgRGBequalizada = cv2.equalizeHist(imgbB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-55-01bba0cd70b1> in <module>()
# ----> 1 imgRGBequalizada = cv2.equalizeHist(imgbB)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/histogram.cpp:3429: error: (-215:Assertion failed) _src.type() == CV_8UC1 in function 'equalizeHist'

# %%
fig7 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig7.add_subplot(1, 2, 1)
x1_plt.imshow(img_NC,cmap=plt.cm.gray)
x2_plt = fig7.add_subplot(1, 2, 2)
x2_plt.imshow(imgGrayequalizada,cmap=plt.cm.gray)

# %% [markdown]
# e)

# %%
fig8 = plt.figure(figsize=(10,10))
plt.subplots_adjust(left=0.125, bottom=0.1, right=1.5, top=1,wspace=0.33, hspace=0.2)
x1_plt = fig7.add_subplot(1, 2, 1)
x1_plt.hist(img_NC.ravel(),256,[0,256])
x2_plt = fig7.add_subplot(1, 2, 2)
x2_plt.hist(imgGrayequalizada.ravel(),256,[0,256])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %% [markdown]
# 3 a)

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0215e6e1-e976-45f5-b359-8c0a6f3f0b76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0215e6e1-e976-45f5-b359-8c0a6f3f0b76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving TD_IR_E_1.jpg to TD_IR_E_1.jpg

# %%
imgGray = cv2.imread("TD_IR_E_1.jpg", cv2.IMREAD_GRAYSCALE)
